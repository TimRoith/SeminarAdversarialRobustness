# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
plt.style.use('ggplot')

x = torch.linspace(-2,3,500)

plt.plot(x,nn.ReLU()(x), label='ReLU')
plt.plot(x,nn.Sigmoid()(x), label='Sigmoid')
plt.plot(x,nn.GELU()(x), label='GELU')
plt.legend()
